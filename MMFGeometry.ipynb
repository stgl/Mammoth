# %%
import numpy as np

XYZ = np.array([[320247, 4166168, 3091.881836],
                [320308, 4166125, 3111.69751],
                [320346, 4166085, 3120.578613],
                [320404, 4166030, 3121.259277],
                [320467, 4165972, 3116.15918],
                [320494, 4165964, 3120.580078],
                [320560, 4165906, 3105.005127],
                [320628, 4165838, 3079.041748],
                [320704, 4165760, 3047.200195],
                [320757, 4165714, 3027.677734],
                [320787, 4165681, 3009.377197],
                [320797, 4165641, 2989.907959],
                [320843, 4165578, 2964.442139],
                [320880, 4165540, 2951.89624],
                [320830, 4165674, 2997.989014],
                [320951, 4165553, 2953.854736],
                [321047, 4165459, 2922.527344],
                [321130, 4165376, 2885.047607],
                [321203, 4165321, 2846.803955],
                [321261, 4165270, 2834.097168],
                [321340, 4165217, 2818.849854],
                [321393, 4165182, 2809.468018],
                [321446, 4165134, 2797.654297],
                [321488, 4165084, 2782.282715],
                [321529, 4165021, 2772.769287],
                [319816, 4166522, 3065.959717],
                [319864, 4166479, 3059.708008],
                [319902, 4166438, 3039.483398],
                [319947, 4166390, 3024.093506],
                [319475, 4166850, 3068.229736],
                [319402, 4166921, 3054.56958],
                [319352, 4166959, 3048.763184],
                [319301, 4167009, 3042.274414],
                [319261, 4167036, 3022.620117],
                [319219, 4167056, 3007.11499]])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
fig.set_size_inches(12, 12)

ax = plt.axes(projection='3d', proj_type='ortho')
ax.plot3D(XYZ[:,0],XYZ[:,1],XYZ[:,2],'k.')
ax.set_box_aspect([np.ptp(XYZ[:,0]),np.ptp(XYZ[:,1]),np.ptp(XYZ[:,2])])

# %%
fig = plt.figure()
fig.set_size_inches(12, 12)

ax = plt.axes(projection='3d', proj_type='ortho')
ax.plot3D(XYZ[:,0],XYZ[:,1],XYZ[:,2],'k.')
ax.view_init(elev = 0.0, azim = 49)
ax.set_box_aspect([np.ptp(XYZ[:,0]),np.ptp(XYZ[:,1]),np.ptp(XYZ[:,2])])

# %%
fig = plt.figure()
fig.set_size_inches(12, 12)

ax = plt.axes(projection='3d')
ax.plot3D(XYZ[:,0],XYZ[:,1],XYZ[:,2],'k.')
ax.view_init(elev = 0.0, azim = 139)
ax.set_box_aspect([np.ptp(XYZ[:,0]),np.ptp(XYZ[:,1]),np.ptp(XYZ[:,2])])
