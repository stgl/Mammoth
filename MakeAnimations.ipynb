# %%
import pickle as p

# %%
(t, co2_ts, co2_pred, co2_erfc_pred, b) = p.load(open('results/ec_time_series.p', 'rb'))
(my_network, my_time_series) = p.load(open('data/GPSData.p', 'rb'))

strain_calculator = my_network.get_strain_calculator([0.001, 0.001], strain_method='gpsgridder', strain_range=[-119.2,-118.6,37.47,37.82])

# %%
import matplotlib.pylab as plt
from matplotlib.gridspec import GridSpec
from plotting import plot_dilatation
from gpsutils import strain_from_network_for_date
import numpy as np

# %%
def plot_animation_frame(fig, date):
    [lons, lats, rot_grd, exx_grd, exy_grd, eyy_grd] = strain_from_network_for_date(strain_calculator, my_time_series, np.datetime64(date), field_prefix = 'filtered')
    gs = GridSpec(2, 1, height_ratios=[7, 2])
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)
    plt.sca(ax1)
    plot_dilatation(lons, lats, exx_grd*1E9, exy_grd*1E9, eyy_grd*1E9, strain_calculator.strain_range, width=2000, eigs_dec = 30, do_not_print_value = 400.0, overmax_scale = 400.0, scale = 1E-4)
    my_network.plot(axis = [-119.2,-118.6,37.47,37.82])
    plt.axis('scaled')
    plt.axis([-119.2,-118.6,37.47,37.82])
    plt.sca(ax2)
    plt.plot(t, co2_ts,'k.')
    plt.plot(t, co2_pred,'g-')
    plt.plot(t, co2_erfc_pred + b, 'r-')
    plt.plot([date, date], [-1000, 6200], 'b-', linewidth = 3)
    ax1.set_position(gs[0].get_position(fig))
    ax2.set_position(gs[1].get_position(fig))
    ax1.set_anchor("W")
    ax2.set_anchor("W")

# %%
from datetime import datetime

fig = plt.figure()
fig.set_size_inches(18, 12)
plot_animation_frame(fig, datetime(2015, 7, 17))

# %%
from datetime import datetime

fig = plt.figure()
fig.set_size_inches(18, 12)
plot_animation_frame(fig, datetime(2018, 1, 17))

# %%
from utils import daterange
from matplotlib.animation import FFMpegWriter

metadata = dict(title='Strain and EC Flux Animation', artist='George Hilley',
                comment='Animation to relate strains to gas efflux at HSL')
writer = FFMpegWriter(fps=15, metadata=metadata)

fig = plt.figure()
fig.set_size_inches(18, 12)

min_t = datetime(2014, 7, 22)
max_t = datetime(2020, 5, 24)
last_month = datetime.month

with writer.saving(fig, "results/StrainECFluxAnimation.mp4", dpi = 100):
    for time in daterange(min_t, max_t):
        plot_animation_frame(fig, time)
        writer.grab_frame()
        fig.clf()
        if time.month != last_month:
            print(time)
            last_month = time.month
# Out:
# 2014-07-22 00:00:00
# 2014-08-01 00:00:00
# 2014-09-01 00:00:00
# 2014-10-01 00:00:00
# 2014-11-01 00:00:00
# 2014-12-01 00:00:00
# 2015-01-01 00:00:00
# 2015-02-01 00:00:00
# 2015-03-01 00:00:00
# 2015-04-01 00:00:00
# 2015-05-01 00:00:00
# 2015-06-01 00:00:00
# 2015-07-01 00:00:00
# 2015-08-01 00:00:00
# 2015-09-01 00:00:00
# 2015-10-01 00:00:00
# 2015-11-01 00:00:00
# 2015-12-01 00:00:00
# 2016-01-01 00:00:00
# 2016-02-01 00:00:00
# 2016-03-01 00:00:00
# 2016-04-01 00:00:00
# 2016-05-01 00:00:00
# 2016-06-01 00:00:00
# 2016-07-01 00:00:00
# 2016-08-01 00:00:00
# 2016-09-01 00:00:00
# 2016-10-01 00:00:00
# 2016-11-01 00:00:00
# 2016-12-01 00:00:00
# 2017-01-01 00:00:00
# 2017-02-01 00:00:00
# 2017-03-01 00:00:00
# 2017-04-01 00:00:00
# 2017-05-01 00:00:00
# 2017-06-01 00:00:00
# 2017-07-01 00:00:00
# 2017-08-01 00:00:00
# 2017-09-01 00:00:00
# 2017-10-01 00:00:00
# 2017-11-01 00:00:00
# 2017-12-01 00:00:00
# 2018-01-01 00:00:00
# 2018-02-01 00:00:00
# 2018-03-01 00:00:00
# 2018-04-01 00:00:00
# 2018-05-01 00:00:00
# 2018-06-01 00:00:00
# 2018-07-01 00:00:00
# 2018-08-01 00:00:00
# 2018-09-01 00:00:00
# 2018-10-01 00:00:00
# 2018-11-01 00:00:00
# 2018-12-01 00:00:00
# 2019-01-01 00:00:00
# 2019-02-01 00:00:00
# 2019-03-01 00:00:00
# 2019-04-01 00:00:00
# 2019-05-01 00:00:00
# 2019-06-01 00:00:00
# 2019-07-01 00:00:00
# 2019-08-01 00:00:00
# 2019-09-01 00:00:00
# 2019-10-01 00:00:00
# 2019-11-01 00:00:00
# 2019-12-01 00:00:00
# 2020-01-01 00:00:00
# 2020-02-01 00:00:00
# 2020-03-01 00:00:00
# 2020-04-01 00:00:00
# 2020-05-01 00:00:00
